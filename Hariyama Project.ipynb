# %%
import csv
from typing import List
from datetime import datetime
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn.datasets
import seaborn as sns
df_twitchglobaldata= pd.read_csv("Twitch_global_data.csv")
df_Twitch_game_data= pd.read_csv("Twitch_game_data.csv")
df_twitchdataupdate= pd.read_csv("twitchdata-update.csv")

# %%
df_twitchglobaldata
# Out:
#     year  Month  Hours_watched  Avg_viewers  Peak_viewers   Streams  \
# 0   2016      1      480241904       646355       1275257   7701675
# 1   2016      2      441859897       635769       1308032   7038520
# 2   2016      3      490669308       660389       1591551   7390957
# 3   2016      4      377975447       525696       1775120   6869719
# 4   2016      5      449836631       605432       1438962   7535519
# ..   ...    ...            ...          ...           ...       ...
# 66  2021      7     1953900874      2629745       4396750  21055358
# 67  2021      8     1974586275      2657585       4778502  20767741
# 68  2021      9     1857514531      2583469       5599210  18826493
# 69  2021     10     2020197953      2718974       6086487  18209793
# 70  2021     11     1812117484      2520330       5941684  17415525
#
#     Avg_channels Games_streamed
# 0          20076         12,149
# 1          20427         12,134
# 2          20271         12,234
# ...

# %%
df_Twitch_game_data
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 14195   196                       War Thunder     11  2021         645300
# 14196   197                             Dofus     11  2021         645248
# 14197   198             Monster Hunter: World     11  2021         635375
# 14198   199             Gas Station Simulator     11  2021         617396
# 14199   200                     Knight Online     11  2021         607581
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
df_twitchdataupdate
# Out:
#               Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0               xQcOW           6196161750                215250
# 1            summit1g           6091677300                211845
# 2              Gaules           5644590915                515280
# 3            ESL_CSGO           3970318140                517740
# 4                Tfue           3671000070                123660
# ..                ...                  ...                   ...
# 995         LITkillah            122524635                 13560
# 996  빅헤드 (bighead033)            122523705                153000
# 997    마스카 (newmasca)            122452320                217410
# 998     AndyMilonakis            122311065                104745
# 999              Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
January=df_twitchglobaldata[df_twitchglobaldata["Month"]==1]
Febuary=df_twitchglobaldata[df_twitchglobaldata["Month"]==2]
March=df_twitchglobaldata[df_twitchglobaldata["Month"]==3]
April=df_twitchglobaldata[df_twitchglobaldata["Month"]==4]
May=df_twitchglobaldata[df_twitchglobaldata["Month"]==5]
June=df_twitchglobaldata[df_twitchglobaldata["Month"]==6]
July=df_twitchglobaldata[df_twitchglobaldata["Month"]==7]
August=df_twitchglobaldata[df_twitchglobaldata["Month"]==8]
September=df_twitchglobaldata[df_twitchglobaldata["Month"]==9]
October=df_twitchglobaldata[df_twitchglobaldata["Month"]==10]
November=df_twitchglobaldata[df_twitchglobaldata["Month"]==11]
December=df_twitchglobaldata[df_twitchglobaldata["Month"]==12]
January
# Out:
#     year  Month  Hours_watched  Avg_viewers  Peak_viewers   Streams  \
# 0   2016      1      480241904       646355       1275257   7701675
# 12  2017      1      601251200       809220       2284184   8672879
# 24  2018      1      720220030       969340       2315343  11222734
# 36  2019      1      949050474      1277322       2278352  17042119
# 48  2020      1     1010010231      1359367       2400513  15053038
# 60  2021      1     2173794168      2925698       6516666  25614207
#
#     Avg_channels Games_streamed
# 0          20076         12,149
# 12         24081         14,841
# 24         33580         18,309
# 36         55853         19,995
# 48         52875         21,249
# 60        119448         34,551

# %%
veri =([["January", January["Hours_watched"].sum()],
                 ["Febuary", Febuary["Hours_watched"].sum()], 
                 ["March", March["Hours_watched"].sum()],
                 ["April", April["Hours_watched"].sum()],
                 ["May", May["Hours_watched"].sum()], 
                 ["June", June["Hours_watched"].sum()],
                 ["July", July["Hours_watched"].sum()],
                 ["August", August["Hours_watched"].sum()],
                 ["September", September["Hours_watched"].sum()],
                 ["October", October["Hours_watched"].sum()], 
                 ["November", November["Hours_watched"].sum()],
                 ["December", December["Hours_watched"].sum()]])
sutun_isimleri=['Month','Hours_watched']
df_month = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %% [markdown]
# Change of average viewership statistics by month

# %%
plt.style.use("dark_background")
plt.figure(figsize=(20,7))
plt.bar(df_month.Month,df_month.Hours_watched,width=0.7,linewidth=2,edgecolor='white')
plt.plot(df_month.Month,df_month.Hours_watched,linewidth=2,marker=".",markeredgewidth=1,color='orange')
plt.show()

# %%
a=df_twitchglobaldata[df_twitchglobaldata["year"]==2016]
b=df_twitchglobaldata[df_twitchglobaldata["year"]==2017]
c=df_twitchglobaldata[df_twitchglobaldata["year"]==2018]
d=df_twitchglobaldata[df_twitchglobaldata["year"]==2019]
e=df_twitchglobaldata[df_twitchglobaldata["year"]==2020]
f=df_twitchglobaldata[df_twitchglobaldata["year"]==2021]

# %%
veri =([["2016", a["Hours_watched"].sum()],
                 ["2017", b["Hours_watched"].sum()], 
                 ["2018", c["Hours_watched"].sum()],
                 ["2019", d["Hours_watched"].sum()],
                 ["2020", e["Hours_watched"].sum()], 
                 ["2021", f["Hours_watched"].sum()]])
sutun_isimleri=['Year','Hours_watched']
df_year = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %% [markdown]
# Change of viewership statistics by years

# %%
plt.style.use("dark_background")
plt.figure(figsize=(10,4))
plt.bar(df_year.Year,df_year.Hours_watched,width=0.7,linewidth=2,edgecolor='white')
plt.show()

# %%
veri =([["January", January["Avg_channels"].sum()],
                 ["Febuary", Febuary["Avg_channels"].sum()], 
                 ["March", March["Avg_channels"].sum()],
                 ["April", April["Avg_channels"].sum()],
                 ["May", May["Avg_channels"].sum()], 
                 ["June", June["Avg_channels"].sum()],
                 ["July", July["Avg_channels"].sum()],
                 ["August", August["Avg_channels"].sum()],
                 ["September", September["Avg_channels"].sum()],
                 ["October", October["Avg_channels"].sum()], 
                 ["November", November["Avg_channels"].sum()],
                 ["December", December["Avg_channels"].sum()]])
sutun_isimleri=['Month','Avg_channels']
df_Avg_channels = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %% [markdown]
# Average number of broadcasting channels by month

# %%
plt.style.use("dark_background")
plt.figure(figsize=(20,6))
plt.bar(df_Avg_channels.Month,df_Avg_channels.Avg_channels,width=0.7,linewidth=2,edgecolor='white')
plt.plot(df_Avg_channels.Month,df_Avg_channels.Avg_channels,linewidth=2,marker=".",markeredgewidth=1,color='orange')
plt.show()

# %%
English=df_twitchdataupdate[df_twitchdataupdate["Language"]=='English']
Korean=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Korean']
Russian=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Russian']
Spanish=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Spanish']
French=df_twitchdataupdate[df_twitchdataupdate["Language"]=='French']
Portuguese=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Portuguese']
German=df_twitchdataupdate[df_twitchdataupdate["Language"]=='German']
Chinese=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Chinese']
Turkish=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Turkish']
Italian=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Italian']
Polish=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Polish']
Thai=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Thai']
Japanese=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Japanese']
Czech=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Russian']
Arabic=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Arabic']
Hungarian=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Hungarian']
Slovak=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Slovak']
Finnish=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Finnish']
Swedish=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Swedish']
Greek=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Greek']
Other=df_twitchdataupdate[df_twitchdataupdate["Language"]=='Other']

# %%
veri =([["English", English["Followers"].sum()],
                 ["Korean", Korean["Followers"].sum()], 
                 ["Russian", Russian["Followers"].sum()],
                 ["Spanish", Spanish["Followers"].sum()],
                 ["French", French["Followers"].sum()], 
                 ["Portuguese", Portuguese["Followers"].sum()],
                 ["German", German["Followers"].sum()],
                 ["Chinese", Chinese["Followers"].sum()],
                 ["Turkish", Turkish["Followers"].sum()],
                 ["Polish", Polish["Followers"].sum()], 
                 ["Thai", Thai["Followers"].sum()],
                 ["Japanese", Japanese["Followers"].sum()],
                 ["Czech", Czech["Followers"].sum()],
                 ["Arabic", Arabic["Followers"].sum()], 
                 ["Thai", Thai["Followers"].sum()],
                 ["Hungarian", Hungarian["Followers"].sum()],
                 ["Slovak", Slovak["Followers"].sum()],
                 ["Finnish", Finnish["Followers"].sum()],
                 ["Swedish", Swedish["Followers"].sum()], 
                 ["Greek", Greek["Followers"].sum()],
                 ["Other", Other["Followers"].sum()]
       ])
sutun_isimleri=['Language','Followers']
df_followers = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %% [markdown]
# Number of Followers by Language

# %%
plt.style.use("dark_background")
plt.figure(figsize=(35,12))
plt.bar(df_followers.Language,df_followers.Followers,width=0.7,linewidth=2,edgecolor='white')
plt.show()

# %%
Valorant=df_Twitch_game_data[df_Twitch_game_data["Game"]=='VALORANT']
CsGo=df_Twitch_game_data[df_Twitch_game_data["Game"]=='Counter-Strike: Global Offensive']

# %%
Valorant_watched2020=Valorant[Valorant["Year"]==2020]
Valorant_watched2021=Valorant[Valorant["Year"]==2021]
CsGo_watched2016=CsGo[CsGo["Year"]==2016]
CsGo_watched2017=CsGo[CsGo["Year"]==2017]
CsGo_watched2018=CsGo[CsGo["Year"]==2018]
CsGo_watched2019=CsGo[CsGo["Year"]==2019]
CsGo_watched2020=CsGo[CsGo["Year"]==2020]
CsGo_watched2021=CsGo[CsGo["Year"]==2021]

# %%
veri =([["CsGo", "2016", CsGo_watched2016["Hours_watched"].sum()],
        ["CsGo", "2017", CsGo_watched2017["Hours_watched"].sum()],
        ["CsGo", "2018", CsGo_watched2018["Hours_watched"].sum()],
        ["CsGo","2018", CsGo_watched2019["Hours_watched"].sum()],
        ["CsGo", "2020", CsGo_watched2020["Hours_watched"].sum()],
        ["CsGo", "2021", CsGo_watched2021["Hours_watched"].sum()]])
sutun_isimleri=['Game','Year','Hours_watched']
df_CsGo_watched = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %%
veri =([["Valorant","2020", Valorant_watched2020["Hours_watched"].sum()], 
        ["Valorant","2021", Valorant_watched2021["Hours_watched"].sum()]])
sutun_isimleri=['Game','Year','Hours_watched']
df_Valorant_watched = pd.DataFrame(data=veri, columns=sutun_isimleri)

# %% [markdown]
# Viewership Rates of Valorant and Counter Strike: Global Offensive Games Based on Years

# %%
plt.style.use("dark_background")
plt.figure(figsize=(18,6))
plt.plot(df_CsGo_watched.Year,df_CsGo_watched.Hours_watched,marker=".",markeredgewidth=4,color='green')
plt.plot(df_Valorant_watched.Year,df_Valorant_watched.Hours_watched,linewidth=3,marker=".",markeredgewidth=4,color='orange')
labels=['CsGo','Valorant']
plt.legend(labels)
plt.show()

# %%
a=df_twitchglobaldata[df_twitchglobaldata["year"]==2016]
b=df_twitchglobaldata[df_twitchglobaldata["year"]==2017]
c=df_twitchglobaldata[df_twitchglobaldata["year"]==2018]
d=df_twitchglobaldata[df_twitchglobaldata["year"]==2019]
e=df_twitchglobaldata[df_twitchglobaldata["year"]==2020]
f=df_twitchglobaldata[df_twitchglobaldata["year"]==2021]

# %% [markdown]
# Change of viewership statistics by month

# %%
plt.style.use("dark_background")
plt.figure(figsize=(15,8))
plt.xlabel('Month')
plt.ylabel('Hours Watched')
plt.plot(a.Month,a.Hours_watched,color='blue',linewidth=3)
plt.plot(b.Month,b.Hours_watched,color='pink',linewidth=3)
plt.plot(c.Month,c.Hours_watched,color='green',linewidth=3)
plt.plot(d.Month,d.Hours_watched,color='red',linewidth=3)
plt.plot(e.Month,e.Hours_watched,color='lightblue',linewidth=3)
plt.plot(f.Month,f.Hours_watched,color='orange',linewidth=3)
labels=['2016','2017','2018','2019','2020','2021']
plt.legend(labels)
plt.show()

# %%
data_prepared=df_twitchdataupdate.dropna()

# %%
data_prepared
# Out:
#               Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0               xQcOW           6196161750                215250
# 1            summit1g           6091677300                211845
# 2              Gaules           5644590915                515280
# 3            ESL_CSGO           3970318140                517740
# 4                Tfue           3671000070                123660
# ..                ...                  ...                   ...
# 995         LITkillah            122524635                 13560
# 996  빅헤드 (bighead033)            122523705                153000
# 997    마스카 (newmasca)            122452320                217410
# 998     AndyMilonakis            122311065                104745
# 999              Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
#Number distribution of languages used in channels streaming on Twitch
data_prepared["Language"].value_counts()
# Out:
# English       485
# Korean         77
# Russian        74
# Spanish        68
# French         66
# Portuguese     61
# German         49
# Chinese        30
# Turkish        22
# Italian        17
# Polish         12
# Thai           11
# Japanese       10
# Czech           6
# Arabic          5
# Hungarian       2
# Finnish         1
# Slovak          1
# Greek           1
# Swedish         1
# Other           1
# Name: Language, dtype: int64

# %%
#distribution of some languages
data_selected=data_prepared[data_prepared["Language"].isin(["Turkish","English","Russian"])]

# %%
data_selected.head()

# %%
#distribution of some languages
data_selected["Language"].value_counts()

# %%
#distribution of some languages
data_prepared.groupby(by="Language").agg(["min","max"])

# %%
#shows the total stream times by some languages 
sns.set_style("whitegrid")
plt.figure(figsize=(15,5))
sns.set(style="darkgrid")
langs=data_selected["Language"].unique()
for lan in langs:
   sns.distplot(data_selected[data_selected["Language"]==lan]["Stream time(minutes)"])
plt.legend(langs)

# %%
#shows the avarage viewers by some languages 
sns.set_style("whitegrid")
plt.figure(figsize=(15,10))
mtr=data_selected["Language"].unique()
for m in mtr:
   sns.distplot(data_selected[data_selected["Language"]==m]["Average viewers"])
plt.legend(mtr)

# %%
#shows the peak viewers by some languages 
sns.set_style("whitegrid")
plt.figure(figsize=(15,5))
flw=data_selected["Language"].unique()
for f in flw:
   sns.distplot(data_selected[data_selected["Language"]==f]["Peak viewers"])
plt.legend(flw)

# %%
gt=data_selected[(data_selected["Language"]=="English") & (data_selected["Peak viewers"])]
gt.head()

# %%
#What is peak viewers of a channel with average viewers?
plt.figure(figsize=(15,10))
sns.scatterplot(x="Peak viewers",y="Average viewers",color="purple",data=gt)

# %%
#How has the average number of views of the streaming streamers been over the years?
plt.figure(figsize=(15,10))
sns.scatterplot(x="Avg_viewers",y="Streamers",hue="Year",color="purple",data=df_Twitch_game_data)

# %%
gt=data_selected[(data_selected["Language"]=="English") & (data_selected["Followers gained"])]
gt.head()

# %%
#followers gained vs views gained.
plt.figure(figsize=(15,10))
sns.scatterplot(x="Followers gained",y="Views gained",color="red",data=gt)

# %%
df_Twitch_game_data.groupby(by="Game").agg("min","max")

# %%
#distribution of languages
plt.style.use("default")
languge = data_prepared["Language"].value_counts().keys()

values = data_prepared["Language"].value_counts().tolist()
fig = plt.figure()
ax = fig.add_axes([0.1, 10, 5, 7])
New_Colors = ['green','blue','purple','brown','teal','yellow','orange','red','pink','grey','lightblue','maroon','aqua','brown','indigo','silver','violet','tan','plum','brown','beige']
ax.bar(languge, values, color=New_Colors, width=0.7)

plt.xlabel("Languages")  #create bar chard
plt.ylabel("Number of languages")
plt.title("")
plt.savefig('Langugages.jpg')



plt.show()

# %%
#streams time vs averege viewers 
plt.style.use("default")
plt.figure(figsize=(14,7))
sns.lineplot(x="Stream time(minutes)" , y="Average viewers" , hue="Language" , data= data_prepared)
plt.title('Streaming time v/s Average Viewers', fontsize = 20)
plt.legend()
plt.show()

# %%
##distribution of languages
plt.style.use("default")
df1 = data_prepared['Language'].value_counts()
name=df1.index
price=df1.values

fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(name, price,color=New_Colors, edgecolor="aqua")
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)

New_Colors = ['green','blue','purple','brown','teal','yellow','orange','red','pink','grey','lightblue','maroon','aqua','brown','indigo','silver','violet','tan','plum','brown','beige']
 
# Add x, y gridlines
ax.grid(b = True, color = 'grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color = 'grey')
 
# Add Plot Title
ax.set_title('Number distribution of languages used in channels streaming on Twitch',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
#df_twitchdataupdate vs df_twitchdataupdate Heatmap
plt.style.use("default")
plt.figure(figsize=(18,12))
sns.heatmap(data_prepared.corr(), vmin=0, vmax=0.5)
plt.show()

# %%
#Shows how many times some games was rank 1 before
plt.style.use("default")
dataRank=df_Twitch_game_data[df_Twitch_game_data['Rank']==1].Game.value_counts()
ax=sns.barplot(x=dataRank.values, y=dataRank.index)

# %%
df_twitchglobaldata= pd.read_csv("Twitch_global_data.csv")
df_Twitch_game_data= pd.read_csv("Twitch_game_data.csv")
df_twitchdataupdate= pd.read_csv("twitchdata-update.csv")

# %%
plt.style.use("default")
a = df_twitchdataupdate[df_twitchdataupdate["Peak viewers"].max() == df_twitchdataupdate["Peak viewers"]]
gamedata1 =a[["Channel","Watch time(Minutes)","Peak viewers"]]

a1=gamedata1["Watch time(Minutes)"].sum()
a2=gamedata1["Peak viewers"].sum()
print(gamedata1)
b=df_twitchdataupdate[df_twitchdataupdate["Watch time(Minutes)"].max() == df_twitchdataupdate["Watch time(Minutes)"]]
gamedata4 =b[["Channel","Watch time(Minutes)","Peak viewers"]]

b1=gamedata4["Watch time(Minutes)"].sum()
b2=gamedata4["Peak viewers"].sum()
print(gamedata4)
import  seaborn as sns
x = ['Riot Games (riotgames)', 'xQcOW']
y1 = [a1,a2]
y2 = [b2,b1]
print(y2)
print(y1)
# plot stacked bar chart 
plt.bar(x, y1, color='g')
plt.bar(x, y2, bottom=y1, color='y')
plt.show()
n_groups = 2
means_frank = (a1,a2)
means_guido = (b1,b2)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')
# Out:
#                    Channel  Watch time(Minutes)  Peak viewers
# 12  Riot Games (riotgames)           2674646715        639375
#   Channel  Watch time(Minutes)  Peak viewers
# 0   xQcOW           6196161750        222720
# [222720, 6196161750]
# [2674646715, 639375]

# %%
plt.style.use("default")
labels = 'peakviewers gamer', 'max followers gamer'
a = (df_twitchdataupdate[df_twitchdataupdate["Peak viewers"].max() == df_twitchdataupdate["Peak viewers"]]['Followers']).tolist()

b=(df_twitchdataupdate[df_twitchdataupdate["Watch time(Minutes)"].max() == df_twitchdataupdate["Watch time(Minutes)"]]['Followers']).tolist()

sizes = [a[0],b[0]]
print(a[0])
print(b[0])

medals = [32, 15, 12, 29, 25]
colors = ['#f70d1a', '#4cc552']
 

my_circle = plt.Circle((0, 0), 0.7, color='white')

d = plt.pie(sizes, labels=labels, autopct='%1.1f%%',colors=colors,
            startangle=90, labeldistance=1.05)
plt.axis('equal')
plt.gca().add_artist(my_circle)
            
plt.show()
plt.show()
# Out:
# 4487489
# 3246298

# %%
plt.style.use("default")
df_twitchdataupdate= df_twitchdataupdate[['Followers','Partnered']]
df_twitchdataupdate
veri=max(df_twitchdataupdate.groupby('Partnered').get_group(False).get('Followers'))
veri2=max(df_twitchdataupdate.groupby('Partnered').get_group(True).get('Followers'))
minvalue=df_twitchdataupdate
print(veri2)
print(veri)
fig1, ax1 = plt.subplots()

part = "Partnered","NotPartneded"
explode = (0, 0.3)
 
fig = plt.figure(figsize =(10, 7))

mycolors=['maroon','violet']
ax1.axis('equal')
sizes = [veri2,veri]
ax1.pie(sizes, explode=explode, labels=part, autopct='%1.1f%%', shadow=True, startangle=90,colors = mycolors,textprops=dict(color="w")) #pie chard
ax1.set_title("Effect of affiliate title on follower count on Twitch")
ax1.legend(title="Partnered Situtaions", loc="center left", bbox_to_anchor=(0.9, 0.2, 0.5, 1))
    
plt.show()
# Out:
# 8938903
# 2115596

# %%
df_twitchglobaldata= pd.read_csv("Twitch_global_data.csv")
df_Twitch_game_data= pd.read_csv("Twitch_game_data.csv")
df_twitchdataupdate= pd.read_csv("twitchdata-update.csv")

# %%
plt.style.use("default")
a=[]
b=[]
headA= []
index =0  
a= df_Twitch_game_data["Hours_watched"].tolist()
a.sort(reverse=True)
for i in range(10) :
    print(a[i])
j =   df_Twitch_game_data.Hours_watched.index.size-1
while j >=0:
    if a[index]==df_Twitch_game_data.Hours_watched.iloc[j] :
        print(a[index])
        headA.append(a[index])
        print(df_Twitch_game_data.Game.iloc[j])
        b.append(df_Twitch_game_data.Game.iloc[j])
        print(j)
        j=df_Twitch_game_data.Hours_watched.index.size
       
        index=index+1
        if index ==10:
            j=-1;
            break;
    j= j-1
print(index)            
print(b)
# Create a dataframe
print("a" +str( len(headA)))
print("b"+ str(len(b)))
df = pd.DataFrame({'group':headA, 'values':b })

# Reorder it based on the values:
ordered_df = df.sort_values(by='values')
my_range=range(1,len(df.index)+1)
 
# Make the plot
plt.stem(ordered_df['values'])
plt.xticks( my_range, ordered_df['group'],rotation='vertical')
plt.show()
 
# Horizontal version
#plt.hlines(y=my_range, xmin=0, xmax=ordered_df['values'], color='skyblue')
#plt.plot(ordered_df['values'], my_range, "D")
#plt.yticks(my_range, ordered_df['group'])
#plt.show()
# Out:
# 344551979
# 289547911
# 285948196
# 270395369
# 253419456
# 252985317
# 249610555
# 248573448
# 248144653
# 240445690
# 344551979
# VALORANT
# 10200
# 289547911
# Just Chatting
# 12600
# 285948196
# Just Chatting
# 12800
# 270395369
# Just Chatting
# 12400
# 253419456
# Grand Theft Auto V
# 12801
# 252985317
# Just Chatting
# 13000
# 249610555
# Just Chatting
# 13400
# 248573448
# Just Chatting
# 11800
# 248144653
# Just Chatting
# 12000
# 240445690
# Just Chatting
# 12200
# 10
# ['VALORANT', 'Just Chatting', 'Just Chatting', 'Just Chatting', 'Grand Theft Auto V', 'Just Chatting', 'Just Chatting', 'Just Chatting', 'Just Chatting', 'Just Chatting']
# a10
# b10

# %%
print(df_twitchdataupdate.dtypes)

# %%
import matplotlib.pyplot as plt
import numpy as np
Just=df_Twitch_game_data[df_Twitch_game_data["Game"]=='Just Chatting']
gamedata4 =Just[["Month","Year","Streamers"]]
#print(gamedata4)
y2018=gamedata4.groupby('Year').get_group(2018).get('Streamers').sum()
y2019=gamedata4.groupby('Year').get_group(2019).get('Streamers').sum()
y2020=gamedata4.groupby('Year').get_group(2020).get('Streamers').sum()
y2021=gamedata4.groupby('Year').get_group(2021).get('Streamers').sum()
VALORANT=df_Twitch_game_data[df_Twitch_game_data["Game"]=='VALORANT']
gamedata2 =VALORANT[["Month","Year","Streamers"]]
#print(gamedata2)
v2021=gamedata2.groupby('Year').get_group(2021).get('Streamers').sum()
v2020=gamedata2.groupby('Year').get_group(2020).get('Streamers').sum()
GTA=df_Twitch_game_data[df_Twitch_game_data["Game"]=='Grand Theft Auto V']
gamedata3 =GTA[["Month","Year","Streamers"]]
#print(gamedata3)
g2016=gamedata3.groupby('Year').get_group(2016).get('Streamers').sum()
g2017=gamedata3.groupby('Year').get_group(2017).get('Streamers').sum()
g2021=gamedata3.groupby('Year').get_group(2021).get('Streamers').sum()
g2018=gamedata3.groupby('Year').get_group(2018).get('Streamers').sum()
g2019=gamedata3.groupby('Year').get_group(2019).get('Streamers').sum()
g2020=gamedata3.groupby('Year').get_group(2020).get('Streamers').sum()
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[y2018, y2019,y2020,y2021,0,0], [v2020, v2021,0,0,0,0 ], [g2016,g2017,g2018,g2019,g2020,g2021]])
group_names=['Just Chatting', 'VALORANT','Grand Theft Auto V']
subgroup_names=['2018', '2019', '2020', '2021','2020', '2021', '2016', '2017','2018', '2019', '2020', '2021']

ax.pie(vals.sum(axis=1), radius=1, wedgeprops=dict(width=size, edgecolor='w'),labels=group_names)

ax.pie(vals.flatten(), radius=1-size, wedgeprops=dict(width=size, edgecolor='w'))
subgroup_names_legs=['Just Chatting', 'VALORANT', 'Grand Theft Auto V', 
'2018', '2019', '2020', '2021', '2020', 
'2020','2016','2017', '2018', '2019', '2020', '2021']
plt.legend(subgroup_names_legs,loc='center right', bbox_to_anchor=(0.9, 0.2, 0.8, 1.1))
ax.set(aspect="equal", title='Playing times of the first 3 categories by years')
plt.show()

# %%
# machine learning

# %%
df_twitchglobaldata= pd.read_csv("Twitch_global_data.csv")
df_Twitch_game_data= pd.read_csv("Twitch_game_data.csv")
df_twitchdataupdate= pd.read_csv("twitchdata-update.csv")

# %%
# drop the Chanel column

# %%
df_twitchdataupdate = df_twitchdataupdate.drop(["Channel"], axis=1)

# %%
# Splitting the Data into Dependent and Independent Variables

# %%
x = df_twitchdataupdate.drop(['Followers gained', 'Partnered',	'Mature',	'Language'], axis=1)
y = df_twitchdataupdate['Followers gained']
x

# %%
# Feature Importance Plot

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
feat_imp = pd.Series(model.feature_importances_, index=x.columns)
feat_imp.plot(kind="barh")

# %%
# Splitting the data into training and test

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=25)

# %%
# Linear Regresion

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain, ytrain)

# %%
# Prediction

# %%
ypred_train = lr.predict(xtrain)
ypred_test = lr.predict(xtest)

# %%
# Calculate accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac1 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac1)

# %%
# Decission Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=5)
dt.fit(xtrain, ytrain)

# %%
# Prediction

# %%
ypred_train = dt.predict(xtrain)
ypred_test = dt.predict(xtest)

# %%
# Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac2 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac2)

# %%
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=8, ccp_alpha=0.05)
rf.fit(xtrain, ytrain)

# %%
# Prediction

# %%
ypred_train = rf.predict(xtrain)
ypred_test = rf.predict(xtest)

# %%
# Accuracy

# %%
from sklearn import metrics
print("Accuracy of training data:", metrics.r2_score(ytrain, ypred_train)*100)
ac3 = metrics.r2_score(ytest, ypred_test)*100
print("Accuracy of testing data:", ac3)

# %%
# Comparing Accuracy

# %%
accuracy =  {ac1: 'Logistic Regression', ac2: 'Decission Tree', ac3:'Random Forest'}
sns.set_style('dark')
plt.figure(figsize=(14, 10))
model_accuracies = list(accuracy.values())
model_names = list(accuracy.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='mako')

# %%
# Prediction

# %%
predict = rf.predict([[6196161750, 215250, 222720, 27716, 3246298, 93036735]])
print("Followers Gained = ", int(predict))

# %%
predict = rf.predict([[6557455931, 5322798, 95563, 33512, 4556874, 4632289]])
print("Followers Gained = ", int(predict))

# %%
predict = rf.predict([[619170, 2150, 27840, 84, 324, 9303]])
print("Followers Gained = ", int(predict))
